# %%
import polars as pl
import json
import gzip

# %%
with gzip.open('../data/2022-01-01-0.json.gz', 'rb') as gzip_file, open('../data/2022-01-01-0.json', 'wb') as decompressed_file:
    decompressed_file.write(gzip_file.read())

# %%
# Specify the path to the input file and output file
input_file_path = '../data/2022-01-01-0.json'
output_file_path = '../data/combined/2022-01-01-0.json'

# Read the input file and load the JSON data
with open(input_file_path, 'r') as f:
    json_data = f.read()

# Split the JSON data into individual dictionaries
dicts = json_data.strip().split('\n')

# Combine the dictionaries into a list
data_list = [json.loads(d) for d in dicts]

# %%
schema = {
    "id": pl.Utf8,
    "type": pl.Utf8,
    "actor": pl.Struct(
        {
            "id": pl.Int32,
            "login": pl.Utf8,
            "display_login": pl.Utf8,
            "gravatar_id": pl.Utf8,
            "url": pl.Utf8,
            "avatar_url": pl.Utf8,
        }
    ),
    "repo": pl.Struct(
        {
            "id": pl.Int32,
            "name": pl.Utf8,
            "url": pl.Utf8,
        }
    ),
    "payload": pl.Struct(
        {
            "push_id": pl.Utf8,
            "size": pl.Int32,
            "distinct_size": pl.Int32,
            "ref": pl.Utf8,
            "head": pl.Utf8,
            "before": pl.Utf8,
            "commits": pl.List(
                pl.Struct(
                    {
                        "sha": pl.Utf8,
                        "author": pl.Struct(
                            {
                                "email": pl.Utf8,
                                "name": pl.Utf8,
                            }
                        ),
                        "message": pl.Utf8,
                        "distinct": pl.Boolean,
                        "url": pl.Utf8,
                    }
                ),
            ),
        }
    ),
    "public": pl.Boolean,
    "created_at": pl.Utf8,
    "org": pl.Struct(
        {
            "id": pl.Int32,
            "login": pl.Utf8,
            "gravatar_id": pl.Utf8,
            "url": pl.Utf8,
            "avatar_url": pl.Utf8,
        }
    ),
    "other": pl.Utf8,
}

# %%
df = pl.from_dicts(data_list, schema=schema)

# %%
# 2022-01-01T00:42:04Z
df = df.with_columns(df['created_at'].str.strptime(pl.Datetime, "%Y-%m-%dT%H:%M:%SZ").alias('created_at'))
df = df.drop('public')
df
# Out:
# shape: (84925, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────┐
# │ id         ┆ type       ┆ actor      ┆ repo       ┆ payload    ┆ created_at ┆ org        ┆ other │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---   │
# │ str        ┆ str        ┆ struct[6]  ┆ struct[3]  ┆ struct[7]  ┆ datetime[μ ┆ struct[5]  ┆ str   │
# │            ┆            ┆            ┆            ┆            ┆ s]         ┆            ┆       │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════╡
# │ 1954117422 ┆ PushEvent  ┆ {85853927, ┆ {443354520 ┆ {"87322920 ┆ 2022-01-01 ┆ {null,null ┆ null  │
# │ 2          ┆            ┆ "Mengrio", ┆ ,"Mengrio/ ┆ 02",1,1,"r ┆ 00:00:00   ┆ ,null,null ┆       │
# │            ┆            ┆ "Mengrio", ┆ Hisoka-Mor ┆ efs/heads/ ┆            ┆ ,null}     ┆       │
# │            ┆            ┆ ""...      ┆ ou...      ┆ ma...      ┆            ┆            ┆       │
# │ 1954117422 ┆ CreateEven ┆ {35642244, ┆ {443443039 ┆ {null,null ┆ 2022-01-01 ┆ {null,null ┆ null  │
# │ 5          ┆ t          ┆ "denis-ond ┆ ,"denis-on ┆ ,null,"mas ┆ 00:00:00   ┆ ,null,null ┆       │
# │            ┆            ┆ er","denis ┆ der/design ┆ ter",null, ┆            ┆ ,null}     ┆       │
# │            ┆            ┆ -o...      ┆ -p...      ┆ nu...      ┆            ┆            ┆       │
# │ 1954117422 ┆ IssueComme ┆ {1145762," ┆ {377296713 ┆ {null,null ┆ 2022-01-01 ┆ {85967389, ┆ null  │
# │ 6          ┆ ntEvent    ┆ sffc","sff ┆ ,"rust-dip ┆ ,null,null ┆ 00:00:00   ┆ "rust-dipl ┆       │
# │            ┆            ┆ c","","htt ┆ lomat/dipl ┆ ,null,null ┆            ┆ omat",""," ┆       │
# │            ┆            ┆ ps...      ┆ om...      ┆ ,n...      ┆            ┆ ht...      ┆       │
# │ 1954117423 ┆ CreateEven ┆ {41898282, ┆ {439105823 ┆ {null,null ┆ 2022-01-01 ┆ {null,null ┆ null  │
# │ 3          ┆ t          ┆ "github-ac ┆ ,"secbyd/l ┆ ,null,"log ┆ 00:00:00   ┆ ,null,null ┆       │
# │            ┆            ┆ tions[bot] ┆ og4shell", ┆ 4shell_inf ┆            ┆ ,null}     ┆       │
# │            ┆            ┆ ",...      ┆ "h...      ┆ o_...      ┆            ┆            ┆       │
# │ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ...   │
# │ 1954139560 ┆ PushEvent  ┆ {41898282, ┆ {358621023 ┆ {"87324328 ┆ 2022-01-01 ┆ {null,null ┆ null  │
# │ 4          ┆            ┆ "github-ac ┆ ,"HOBOJAME ┆ 92",1,1,"r ┆ 00:59:59   ┆ ,null,null ┆       │
# │            ┆            ┆ tions[bot] ┆ S/starter- ┆ efs/heads/ ┆            ┆ ,null}     ┆       │
# │            ┆            ┆ ",...      ┆ ac...      ┆ ma...      ┆            ┆            ┆       │
# │ 1954139560 ┆ PushEvent  ┆ {8517910," ┆ {86929735, ┆ {"87324328 ┆ 2022-01-01 ┆ {8158177," ┆ null  │
# │ 2          ┆            ┆ LombiqBot" ┆ "Lombiq/Or ┆ 91",0,0,"r ┆ 00:59:59   ┆ Lombiq","" ┆       │
# │            ┆            ┆ ,"LombiqBo ┆ chard","ht ┆ efs/heads/ ┆            ┆ ,"https:// ┆       │
# │            ┆            ┆ t"...      ┆ tp...      ┆ se...      ┆            ┆ ap...      ┆       │
# │ 1954139560 ┆ PushEvent  ┆ {81356631, ┆ {353698520 ┆ {"87324328 ┆ 2022-01-01 ┆ {null,null ┆ null  │
# │ 7          ┆            ┆ "cha3ban", ┆ ,"cha3ban/ ┆ 90",1,1,"r ┆ 00:59:59   ┆ ,null,null ┆       │
# │            ┆            ┆ "cha3ban", ┆ goof","htt ┆ efs/heads/ ┆            ┆ ,null}     ┆       │
# │            ┆            ┆ ""...      ┆ ps...      ┆ sn...      ┆            ┆            ┆       │
# │ 1954139561 ┆ PushEvent  ┆ {41898282, ┆ {278426733 ┆ {"87324329 ┆ 2022-01-01 ┆ {null,null ┆ null  │
# │ 2          ┆            ┆ "github-ac ┆ ,"tks18/tk ┆ 00",1,1,"r ┆ 00:59:59   ┆ ,null,null ┆       │
# │            ┆            ┆ tions[bot] ┆ s18","http ┆ efs/heads/ ┆            ┆ ,null}     ┆       │
# │            ┆            ┆ ",...      ┆ s:...      ┆ ou...      ┆            ┆            ┆       │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────┘

# %%
df.write_parquet('./2022-01-01-0.parquet', compression='snappy')
